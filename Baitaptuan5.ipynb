# %%
#A1:iết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( 
#a, b) -> int: 
def Max_Of_Two(a, b):
    if a > b:
        return a
    elif b > a:
        return b
    else:
        return a, b
a, b = map(int, input().split())
print(Max_Of_Two(a, b))
# Out:
#  13 13
# (13, 13)

# %%
#A2:iết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]: 
def swap(a, b):
    a, b = b, a
    return a, b
a, b = map(int, input().split())
print(swap(a, b))
# Out:
#  13 14
# (14, 13)

# %%
#A3: iết hàm kiểm tra một số có phải là số nguyên tố hay không? 
def is_prime(a):
    uoc = 0
    for i in range(1, int(a**0.5)+1):
        if a % i == 0:
            uoc += 1
    if uoc >= 2:
        return False
    else:
        return True
a = int(input())
print(is_prime(a))
# Out:
#  13
# True

# %%
#A4: Iết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên. 
def so_hoan_hao(a):
    tong = 0
    for i in range(1, a//2+1):
        if a % i == 0:
            tong += i
    if tong == a:
        return True
    else:
        return False
a = int(input())
print(so_hoan_hao(a))
# Out:
#  13
# False

# %%
#A5: iết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của 
#phần tử đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1 
def tim_k(a, k):
    vi_tri = 0
    for i in range (len(a)):
        if a[i] == k:
            vi_tri = i
            break
    if k in a:
        return k, vi_tri + 1
    else:
        return -1
a = list(map(int, input().split()))
k = int(input())
print(tim_k(a, k))
# Out:
#  8 6 9 10
#  11
# -1

# %%
#A6: iết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!) 
def giai_thua(a):
    tich = 1
    for i in range (1, n+1):
        tich *= i
    return tich
n = int(input())
print(giai_thua(n))
# Out:
#  3
# 6

# %%
#A7: iết hàm giả lập một máy tính bỏ túi. 
#Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử 
#\( operat \) 
#Biết các toán tử đơn giản thực hiện phép toán lần lượt là: 
#Phép trừ \( - \) 
#Phép cộng \( + \) 
#Phép chia \( / \) 
#Phép nhân \( * \) 
#Kết quả làm tròn đến chữ số thập phân thứ hai. 
#Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)). 
#Đầu ra: Kết quả phép toán. 
def gia_lap_may_tinh(a, b):
    hieu = a - b
    tong = a + b
    chia = a / b
    nhan = a * b
    return hieu, tong, round(chia, 2), nhan
a, b = map(int, input().split())
print(gia_lap_may_tinh(a, b))
# Out:
#  1 3
# (-2, 4, 0.33, 3)

# %%
#A8: hoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits 
#tương ứng của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2. 
#Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này. 
def hamming_distance(x, y) -> int:
    bx = bin(x)[2:]
    by = bin(y)[2:]
    max_len = max(len(bx), len(by))
    while len(bx) < max_len:
        bx = "0" + bx
    while len(by) < max_len:
        by = "0" + by
    count = 0
    for i in range(max_len):
        if bx[i] != by[i]:
            count += 1
    return count
a, b = map(int, input().split())
print(hamming_distance(a, b))
# Out:
#  3 6
# 2

# %%
#A9: Viết hàm trả về tổng các chữ số của số nguyên dương n 
def tong_chu_so(a):
    tong = 0
    while a >= 1:
        tong += a % 10
        a //= 10
    return tong
a = int(input())
print(tong_chu_so(a))
# Out:
#  346
# 13

# %%
#A10: ai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn 
#lại. Ánh xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ 
#tự của các kí tự được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí 
#tự, nhưng một kí tự có thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng 
#cấu vì ta có thể ánh xạ 'a' thành 'z', 'b' thành 'b' và 'c' thành 'x'. 
#Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể 
#giả sử hai từ đầu vào có cùng độ dài
def dang_cau(a, b)-> bool:
    ki_tu_1 = []
    for i in range (len(a)):
        if a[i] not in ki_tu_1:
            ki_tu_1 += a[i]
            b[i] = ord(ki_tu_1[i])
    flag = 'Red'
    for i in range (len(a)):
        if b[i] != ord(a[i]):
            flag = 'Blue'
    if flag == 'Blue':
        return False
    else:
        return True
a, b = map(list, input().split())
print(dang_cau(a, b))
# Out:
#  abca zbxz
# False

# %%
a, b = map(list, input().split())
ki_tu_1 = []
for i in range (len(a)):
    if a[i] not in ki_tu_1:
        ki_tu_1 += a[i]
        b[i] = ord(ki_tu_1[i])
print(b[i])
# Out:
#  abca zbcz
# z
